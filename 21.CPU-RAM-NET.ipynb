# %%
from init import *

# %%
from uuoskit import util

# %% [markdown]
# ```python
# def buyrambytes(payer, receiver, _bytes)
# def buyram(payer, receiver, quant)
# def sellram(account, _bytes)
# def dbw(_from, _to, net, cpu)
# def undbw(_from, _to, net, cpu)
# ```

# %%
uuosapi.get_account(config.python_contract)
# Out:
# {'account_name': 'ceyelqpjeeia',
#  'head_block_num': 45351988,
#  'head_block_time': '2021-01-11T09:26:17.500',
#  'privileged': False,
#  'last_code_update': '2021-01-11T03:14:24.000',
#  'created': '2020-11-30T02:20:16.000',
#  'core_liquid_balance': '78.7595 TNT',
#  'ram_quota': 3810651,
#  'net_weight': 30000,
#  'cpu_weight': 310000,
#  'net_limit': {'used': 408216, 'available': 6780524, 'max': 7188740},
#  'cpu_limit': {'used': 65368, 'available': 14101752, 'max': 14167120},
#  'ram_usage': 2738517,
#  'permissions': [{'perm_name': 'active',
#    'parent': 'owner',
#    'required_auth': {'threshold': 1,
#     'keys': [{'key': 'EOS8moVJwVaR8pb43KBi2HwmtbwebXmjSJUerfwbvFW41tEvYsfDE',
#       'weight': 1}],
#     'accounts': [{'permission': {'actor': 'ceyelqpjeeia',
#        'permission': 'eosio.code'},
#       'weight': 1}],
#     'waits': []}},
#   {'perm_name': 'owner',
#    'parent': '',
#    'required_auth': {'threshold': 1,
#     'keys': [{'key': 'EOS79fssH8wH5EyNtKP2oZAt1b9jfeu6hpna7RJ7eMwwjr73S5kWa',
#       'weight': 1}],
#     'accounts': [],
#     'waits': []}},
#   {'perm_name': 'sayhello',
#    'parent': 'active',
#    'required_auth': {'threshold': 2,
#     'keys': [{'key': 'EOS4yV91cqR6db8ntKtCLFVwWfvvvDMZctpd85GsaX5GUMaiqUWYL',
#       'weight': 1},
#      {'key': 'EOS5gNqDpWm72KzNWFVgBDmybrEtk9qx2ZuAeRbK9iSJMVJ2B8y73',
#       'weight': 1}],
#     'accounts': [],
#     'waits': []}}],
#  'total_resources': {'owner': 'ceyelqpjeeia',
#   'net_weight': '3.0000 TNT',
#   'cpu_weight': '31.0000 TNT',
#   'ram_bytes': 3809251},
#  'self_delegated_bandwidth': {'from': 'ceyelqpjeeia',
#   'to': 'ceyelqpjeeia',
#   'net_weight': '3.0000 TNT',
#   'cpu_weight': '31.0000 TNT'},
#  'refund_request': None,
#  'voter_info': {'owner': 'ceyelqpjeeia',
#   'proxy': '',
#   'producers': [],
#   'staked': 340000,
#   'last_vote_weight': '0.00000000000000000',
#   'proxied_vote_weight': '0.00000000000000000',
#   'is_proxy': 0,
#   'flags1': 0,
#   'reserved2': 0,
#   'reserved3': '0 '},
#  'rex_info': None}

# %% [markdown]
# # def buyram(payer, receiver, _bytes)

# %%
r = uuosapi.get_account(python_contract)['ram_quota']
print(r)
r = uuosapi.get_account(python_contract)['ram_usage']
print(r)
r = uuosapi.get_balance(python_contract)
print(r)
# Out:
# 3810651
# 2738517
# 78.7595

# %%
util.buyram(python_contract, python_contract, 1.0)
# Out:
# {'transaction_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#  'processed': {'id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#   'block_num': 45352613,
#   'block_time': '2021-01-11T09:31:30.000',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 1104,
#    'net_usage_words': 16},
#   'elapsed': 1104,
#   'net_usage': 128,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': '1c2ff069ad9a7fde93e4a40e03909055d6e4ea827f94474d60a24d23951eeb15',
#      'global_sequence': 55795099,
#      'recv_sequence': 45390172,
#      'auth_sequence': [['ceyelqpjeeia', 2337]],
#      'code_sequence': 3,
#      'abi_sequence': 3},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'buyram',
#      'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#      'data': {'payer': 'ceyelqpjeeia',
#       'receiver': 'ceyelqpjeeia',
#       'quant': '1.0000 TNT'},
#      'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000'},
#     'context_free': False,
#     'elapsed': 306,
#     'console': '',
#     'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#     'block_num': 45352613,
#     'block_time': '2021-01-11T09:31:30.000',
#     'producer_block_id': None,
#     'account_ram_deltas': [],
#     'except': None,
#     'error_code': None,
#     'inline_traces': [{'action_ordinal': 2,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.rammon',
#        'act_digest': '1c2ff069ad9a7fde93e4a40e03909055d6e4ea827f94474d60a24d23951eeb15',
#        'global_sequence': 55795100,
#        'recv_sequence': 3161,
#        'auth_sequence': [['ceyelqpjeeia', 2338]],
#        'code_sequence': 3,
#        'abi_sequence': 3},
#       'receiver': 'eosio.rammon',
#       'act': {'account': 'eosio',
#        'name': 'buyram',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'payer': 'ceyelqpjeeia',
#         'receiver': 'ceyelqpjeeia',
#         'quant': '1.0000 TNT'},
#        'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000'},
#       'context_free': False,
#       'elapsed': 67,
#       'console': '',
#       'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#       'block_num': 45352613,
#       'block_time': '2021-01-11T09:31:30.000',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': []},
#      {'action_ordinal': 3,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': '74463e65b4ac8a12d4164134a241847ee69e2013c7412ae2a08afb28bbf06277',
#        'global_sequence': 55795101,
#        'recv_sequence': 61606,
#        'auth_sequence': [['ceyelqpjeeia', 2339], ['eosio.ram', 20920]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#         {'actor': 'eosio.ram', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.ram',
#         'quantity': '0.9950 TNT',
#         'memo': 'buy ram'},
#        'hex_data': '609c52afdaa8bc42000090e602ea3055de2600000000000004544e5400000000076275792072616d'},
#       'context_free': False,
#       'elapsed': 79,
#       'console': '',
#       'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#       'block_num': 45352613,
#       'block_time': '2021-01-11T09:31:30.000',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 5,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': '74463e65b4ac8a12d4164134a241847ee69e2013c7412ae2a08afb28bbf06277',
#          'global_sequence': 55795102,
#          'recv_sequence': 3733,
#          'auth_sequence': [['ceyelqpjeeia', 2340], ['eosio.ram', 20921]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#           {'actor': 'eosio.ram', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ram',
#           'quantity': '0.9950 TNT',
#           'memo': 'buy ram'},
#          'hex_data': '609c52afdaa8bc42000090e602ea3055de2600000000000004544e5400000000076275792072616d'},
#         'context_free': False,
#         'elapsed': 222,
#         'console': '',
#         'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#         'block_num': 45352613,
#         'block_time': '2021-01-11T09:31:30.000',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 6,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'eosio.ram',
#          'act_digest': '74463e65b4ac8a12d4164134a241847ee69e2013c7412ae2a08afb28bbf06277',
#          'global_sequence': 55795103,
#          'recv_sequence': 6974,
#          'auth_sequence': [['ceyelqpjeeia', 2341], ['eosio.ram', 20922]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ram',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#           {'actor': 'eosio.ram', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ram',
#           'quantity': '0.9950 TNT',
#           'memo': 'buy ram'},
#          'hex_data': '609c52afdaa8bc42000090e602ea3055de2600000000000004544e5400000000076275792072616d'},
#         'context_free': False,
#         'elapsed': 2,
#         'console': '',
#         'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#         'block_num': 45352613,
#         'block_time': '2021-01-11T09:31:30.000',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]},
#      {'action_ordinal': 4,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': '30fd3d12d2e408db846d00e3b0d37c5f46ffbb590dff2bbc58c45033d8daec5b',
#        'global_sequence': 55795104,
#        'recv_sequence': 61607,
#        'auth_sequence': [['ceyelqpjeeia', 2342]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.ramfee',
#         'quantity': '0.0050 TNT',
#         'memo': 'ram fee'},
#        'hex_data': '609c52afdaa8bc42a0d492e602ea3055320000000000000004544e54000000000772616d20666565'},
#       'context_free': False,
#       'elapsed': 55,
#       'console': '',
#       'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#       'block_num': 45352613,
#       'block_time': '2021-01-11T09:31:30.000',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 7,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': '30fd3d12d2e408db846d00e3b0d37c5f46ffbb590dff2bbc58c45033d8daec5b',
#          'global_sequence': 55795105,
#          'recv_sequence': 3734,
#          'auth_sequence': [['ceyelqpjeeia', 2343]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0050 TNT',
#           'memo': 'ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055320000000000000004544e54000000000772616d20666565'},
#         'context_free': False,
#         'elapsed': 191,
#         'console': '',
#         'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#         'block_num': 45352613,
#         'block_time': '2021-01-11T09:31:30.000',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 8,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'eosio.ramfee',
#          'act_digest': '30fd3d12d2e408db846d00e3b0d37c5f46ffbb590dff2bbc58c45033d8daec5b',
#          'global_sequence': 55795106,
#          'recv_sequence': 6974,
#          'auth_sequence': [['ceyelqpjeeia', 2344]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ramfee',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0050 TNT',
#           'memo': 'ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055320000000000000004544e54000000000772616d20666565'},
#         'context_free': False,
#         'elapsed': 5,
#         'console': '',
#         'trx_id': '9f259dc79f180f8b95dce3c4bdfebae9df67327ad0581d1f5da7f0c868dcea82',
#         'block_num': 45352613,
#         'block_time': '2021-01-11T09:31:30.000',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]}]}],
#   'account_ram_delta': None,
#   'except': None,
#   'error_code': None}}

# %%
r = uuosapi.get_account(python_contract)['ram_quota']
print(r)
r = uuosapi.get_account(python_contract)['ram_usage']
print(r)
r = uuosapi.get_balance(python_contract)
print(r)
# Out:
# 3875712
# 2739738
# 77.7595

# %% [markdown]
# # def buyrambytes(payer, receiver, quant)

# %%
r = uuosapi.get_account(python_contract)['ram_quota']
print(r)
r = uuosapi.get_account(python_contract)['ram_usage']
print(r)
r = uuosapi.get_balance(python_contract)
print(r)
# Out:
# 3875712
# 2739738
# 77.7595

# %%
util.buyrambytes(python_contract, python_contract, 1024)
# Out:
# {'transaction_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#  'processed': {'id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#   'block_num': 45352818,
#   'block_time': '2021-01-11T09:33:12.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 1112,
#    'net_usage_words': 14},
#   'elapsed': 1112,
#   'net_usage': 112,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'bcf73254f437240a7d6837d23384bb8697920d7e0980ddbc976991e401df5fd9',
#      'global_sequence': 55795326,
#      'recv_sequence': 45390378,
#      'auth_sequence': [['ceyelqpjeeia', 2345]],
#      'code_sequence': 3,
#      'abi_sequence': 3},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'buyrambytes',
#      'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#      'data': {'payer': 'ceyelqpjeeia',
#       'receiver': 'ceyelqpjeeia',
#       'bytes': 1024},
#      'hex_data': '609c52afdaa8bc42609c52afdaa8bc4200040000'},
#     'context_free': False,
#     'elapsed': 306,
#     'console': '',
#     'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#     'block_num': 45352818,
#     'block_time': '2021-01-11T09:33:12.500',
#     'producer_block_id': None,
#     'account_ram_deltas': [],
#     'except': None,
#     'error_code': None,
#     'inline_traces': [{'action_ordinal': 2,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.rammon',
#        'act_digest': 'bcf73254f437240a7d6837d23384bb8697920d7e0980ddbc976991e401df5fd9',
#        'global_sequence': 55795327,
#        'recv_sequence': 3162,
#        'auth_sequence': [['ceyelqpjeeia', 2346]],
#        'code_sequence': 3,
#        'abi_sequence': 3},
#       'receiver': 'eosio.rammon',
#       'act': {'account': 'eosio',
#        'name': 'buyrambytes',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'payer': 'ceyelqpjeeia',
#         'receiver': 'ceyelqpjeeia',
#         'bytes': 1024},
#        'hex_data': '609c52afdaa8bc42609c52afdaa8bc4200040000'},
#       'context_free': False,
#       'elapsed': 53,
#       'console': '',
#       'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#       'block_num': 45352818,
#       'block_time': '2021-01-11T09:33:12.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': []},
#      {'action_ordinal': 3,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': 'c3e6c4374b3d91c8e812641bd8dc2310ade6978c3017fcf5455e0f553aa20391',
#        'global_sequence': 55795328,
#        'recv_sequence': 61608,
#        'auth_sequence': [['ceyelqpjeeia', 2347], ['eosio.ram', 20923]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#         {'actor': 'eosio.ram', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.ram',
#         'quantity': '0.0155 TNT',
#         'memo': 'buy ram'},
#        'hex_data': '609c52afdaa8bc42000090e602ea30559b0000000000000004544e5400000000076275792072616d'},
#       'context_free': False,
#       'elapsed': 82,
#       'console': '',
#       'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#       'block_num': 45352818,
#       'block_time': '2021-01-11T09:33:12.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 5,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': 'c3e6c4374b3d91c8e812641bd8dc2310ade6978c3017fcf5455e0f553aa20391',
#          'global_sequence': 55795329,
#          'recv_sequence': 3735,
#          'auth_sequence': [['ceyelqpjeeia', 2348], ['eosio.ram', 20924]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#           {'actor': 'eosio.ram', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ram',
#           'quantity': '0.0155 TNT',
#           'memo': 'buy ram'},
#          'hex_data': '609c52afdaa8bc42000090e602ea30559b0000000000000004544e5400000000076275792072616d'},
#         'context_free': False,
#         'elapsed': 220,
#         'console': '',
#         'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#         'block_num': 45352818,
#         'block_time': '2021-01-11T09:33:12.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 6,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'eosio.ram',
#          'act_digest': 'c3e6c4374b3d91c8e812641bd8dc2310ade6978c3017fcf5455e0f553aa20391',
#          'global_sequence': 55795330,
#          'recv_sequence': 6975,
#          'auth_sequence': [['ceyelqpjeeia', 2349], ['eosio.ram', 20925]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ram',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'},
#           {'actor': 'eosio.ram', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ram',
#           'quantity': '0.0155 TNT',
#           'memo': 'buy ram'},
#          'hex_data': '609c52afdaa8bc42000090e602ea30559b0000000000000004544e5400000000076275792072616d'},
#         'context_free': False,
#         'elapsed': 3,
#         'console': '',
#         'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#         'block_num': 45352818,
#         'block_time': '2021-01-11T09:33:12.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]},
#      {'action_ordinal': 4,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': '27c79b1a3418c3a7e7a04e23b6cb372c59a2667ade7396265e144f011f7d8d4e',
#        'global_sequence': 55795331,
#        'recv_sequence': 61609,
#        'auth_sequence': [['ceyelqpjeeia', 2350]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.ramfee',
#         'quantity': '0.0001 TNT',
#         'memo': 'ram fee'},
#        'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000772616d20666565'},
#       'context_free': False,
#       'elapsed': 54,
#       'console': '',
#       'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#       'block_num': 45352818,
#       'block_time': '2021-01-11T09:33:12.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 7,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': '27c79b1a3418c3a7e7a04e23b6cb372c59a2667ade7396265e144f011f7d8d4e',
#          'global_sequence': 55795332,
#          'recv_sequence': 3736,
#          'auth_sequence': [['ceyelqpjeeia', 2351]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0001 TNT',
#           'memo': 'ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000772616d20666565'},
#         'context_free': False,
#         'elapsed': 192,
#         'console': '',
#         'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#         'block_num': 45352818,
#         'block_time': '2021-01-11T09:33:12.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 8,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'eosio.ramfee',
#          'act_digest': '27c79b1a3418c3a7e7a04e23b6cb372c59a2667ade7396265e144f011f7d8d4e',
#          'global_sequence': 55795333,
#          'recv_sequence': 6975,
#          'auth_sequence': [['ceyelqpjeeia', 2352]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ramfee',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0001 TNT',
#           'memo': 'ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000772616d20666565'},
#         'context_free': False,
#         'elapsed': 5,
#         'console': '',
#         'trx_id': 'c0640dd5c38028155b3bf15e83604021261e7aae79bc4db72ae5d4def2bc3107',
#         'block_num': 45352818,
#         'block_time': '2021-01-11T09:33:12.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]}]}],
#   'account_ram_delta': None,
#   'except': None,
#   'error_code': None}}

# %%
r = uuosapi.get_account(python_contract)['ram_quota']
print(r)
r = uuosapi.get_account(python_contract)['ram_usage']
print(r)
r = uuosapi.get_balance(python_contract)
print(r)
# Out:
# 3876725
# 2739738
# 77.7439

# %% [markdown]
# # def sellram(account, _bytes)

# %%
balance = uuosapi.get_balance(python_contract)
print(balance)
ram_quota = uuosapi.get_account(python_contract)['ram_quota']
print(ram_quota)
# Out:
# 77.7439
# 3876725

# %%
util.sellram(python_contract, 1024)
# Out:
# {'transaction_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#  'processed': {'id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#   'block_num': 45352964,
#   'block_time': '2021-01-11T09:34:25.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 1138,
#    'net_usage_words': 14},
#   'elapsed': 1138,
#   'net_usage': 112,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'ce4243ae6f66a8206b9c739d17e44092ddcb68aa12a57a8316db5d837d0f983a',
#      'global_sequence': 55795489,
#      'recv_sequence': 45390525,
#      'auth_sequence': [['ceyelqpjeeia', 2353]],
#      'code_sequence': 3,
#      'abi_sequence': 3},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'sellram',
#      'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#      'data': {'account': 'ceyelqpjeeia', 'bytes': 1024},
#      'hex_data': '609c52afdaa8bc420004000000000000'},
#     'context_free': False,
#     'elapsed': 311,
#     'console': '',
#     'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#     'block_num': 45352964,
#     'block_time': '2021-01-11T09:34:25.500',
#     'producer_block_id': None,
#     'account_ram_deltas': [],
#     'except': None,
#     'error_code': None,
#     'inline_traces': [{'action_ordinal': 2,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.rammon',
#        'act_digest': 'ce4243ae6f66a8206b9c739d17e44092ddcb68aa12a57a8316db5d837d0f983a',
#        'global_sequence': 55795490,
#        'recv_sequence': 3163,
#        'auth_sequence': [['ceyelqpjeeia', 2354]],
#        'code_sequence': 3,
#        'abi_sequence': 3},
#       'receiver': 'eosio.rammon',
#       'act': {'account': 'eosio',
#        'name': 'sellram',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'account': 'ceyelqpjeeia', 'bytes': 1024},
#        'hex_data': '609c52afdaa8bc420004000000000000'},
#       'context_free': False,
#       'elapsed': 63,
#       'console': '',
#       'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#       'block_num': 45352964,
#       'block_time': '2021-01-11T09:34:25.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': []},
#      {'action_ordinal': 3,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': 'cb0e0b5e18842762ae03f99940ccf50afd7e785e59592139532e1031228caaed',
#        'global_sequence': 55795491,
#        'recv_sequence': 61610,
#        'auth_sequence': [['ceyelqpjeeia', 2355], ['eosio.ram', 20926]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'eosio.ram', 'permission': 'active'},
#         {'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'eosio.ram',
#         'to': 'ceyelqpjeeia',
#         'quantity': '0.0156 TNT',
#         'memo': 'sell ram'},
#        'hex_data': '000090e602ea3055609c52afdaa8bc429c0000000000000004544e54000000000873656c6c2072616d'},
#       'context_free': False,
#       'elapsed': 81,
#       'console': '',
#       'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#       'block_num': 45352964,
#       'block_time': '2021-01-11T09:34:25.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 5,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'eosio.ram',
#          'act_digest': 'cb0e0b5e18842762ae03f99940ccf50afd7e785e59592139532e1031228caaed',
#          'global_sequence': 55795492,
#          'recv_sequence': 6976,
#          'auth_sequence': [['ceyelqpjeeia', 2356], ['eosio.ram', 20927]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ram',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'eosio.ram', 'permission': 'active'},
#           {'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'eosio.ram',
#           'to': 'ceyelqpjeeia',
#           'quantity': '0.0156 TNT',
#           'memo': 'sell ram'},
#          'hex_data': '000090e602ea3055609c52afdaa8bc429c0000000000000004544e54000000000873656c6c2072616d'},
#         'context_free': False,
#         'elapsed': 2,
#         'console': '',
#         'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#         'block_num': 45352964,
#         'block_time': '2021-01-11T09:34:25.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 6,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': 'cb0e0b5e18842762ae03f99940ccf50afd7e785e59592139532e1031228caaed',
#          'global_sequence': 55795493,
#          'recv_sequence': 3737,
#          'auth_sequence': [['ceyelqpjeeia', 2357], ['eosio.ram', 20928]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'eosio.ram', 'permission': 'active'},
#           {'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'eosio.ram',
#           'to': 'ceyelqpjeeia',
#           'quantity': '0.0156 TNT',
#           'memo': 'sell ram'},
#          'hex_data': '000090e602ea3055609c52afdaa8bc429c0000000000000004544e54000000000873656c6c2072616d'},
#         'context_free': False,
#         'elapsed': 236,
#         'console': '',
#         'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#         'block_num': 45352964,
#         'block_time': '2021-01-11T09:34:25.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]},
#      {'action_ordinal': 4,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': '7c5aa0b3c5a6921b4d6674170f6f67b8c4635dac6ae0a00a0c65b29613c3e33d',
#        'global_sequence': 55795494,
#        'recv_sequence': 61611,
#        'auth_sequence': [['ceyelqpjeeia', 2358]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.ramfee',
#         'quantity': '0.0001 TNT',
#         'memo': 'sell ram fee'},
#        'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000c73656c6c2072616d20666565'},
#       'context_free': False,
#       'elapsed': 59,
#       'console': '',
#       'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#       'block_num': 45352964,
#       'block_time': '2021-01-11T09:34:25.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 7,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': '7c5aa0b3c5a6921b4d6674170f6f67b8c4635dac6ae0a00a0c65b29613c3e33d',
#          'global_sequence': 55795495,
#          'recv_sequence': 3738,
#          'auth_sequence': [['ceyelqpjeeia', 2359]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0001 TNT',
#           'memo': 'sell ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000c73656c6c2072616d20666565'},
#         'context_free': False,
#         'elapsed': 196,
#         'console': '',
#         'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#         'block_num': 45352964,
#         'block_time': '2021-01-11T09:34:25.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 8,
#         'creator_action_ordinal': 4,
#         'closest_unnotified_ancestor_action_ordinal': 4,
#         'receipt': {'receiver': 'eosio.ramfee',
#          'act_digest': '7c5aa0b3c5a6921b4d6674170f6f67b8c4635dac6ae0a00a0c65b29613c3e33d',
#          'global_sequence': 55795496,
#          'recv_sequence': 6976,
#          'auth_sequence': [['ceyelqpjeeia', 2360]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.ramfee',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.ramfee',
#           'quantity': '0.0001 TNT',
#           'memo': 'sell ram fee'},
#          'hex_data': '609c52afdaa8bc42a0d492e602ea3055010000000000000004544e54000000000c73656c6c2072616d20666565'},
#         'context_free': False,
#         'elapsed': 7,
#         'console': '',
#         'trx_id': 'c0c45d3d43ad40443355f1366fafd6e24fbb69c86f9e0348f48abec10b156f27',
#         'block_num': 45352964,
#         'block_time': '2021-01-11T09:34:25.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]}]}],
#   'account_ram_delta': None,
#   'except': None,
#   'error_code': None}}

# %%
balance = uuosapi.get_balance(python_contract)
print(balance)
ram_quota = uuosapi.get_account(python_contract)['ram_quota']
print(ram_quota)
# Out:
# 77.7594
# 3875701

# %% [markdown]
# # def dbw(_from, _to, net, cpu)

# %%
r = uuosapi.get_account(python_contract)['total_resources']
print(r)
r = uuosapi.get_account(python_contract)['cpu_limit']
print(r)
r = uuosapi.get_account(python_contract)['net_limit']
print(r)
# Out:
# {'owner': 'ceyelqpjeeia', 'net_weight': '3.0000 TNT', 'cpu_weight': '31.0000 TNT', 'ram_bytes': 3874301}
# {'used': 56954, 'available': 14110166, 'max': 14167120}
# {'used': 322713, 'available': 6866027, 'max': 7188740}

# %%
util.dbw(python_contract, python_contract, 1.0, 1.0)
# Out:
# {'transaction_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#  'processed': {'id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#   'block_num': 45353152,
#   'block_time': '2021-01-11T09:35:59.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 862,
#    'net_usage_words': 18},
#   'elapsed': 862,
#   'net_usage': 144,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'a54ecb1795be29cacf5efb70c3e6403cb14f38007574cd1e0aa38541790a879f',
#      'global_sequence': 55795698,
#      'recv_sequence': 45390714,
#      'auth_sequence': [['ceyelqpjeeia', 2361]],
#      'code_sequence': 3,
#      'abi_sequence': 3},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'delegatebw',
#      'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#      'data': {'from': 'ceyelqpjeeia',
#       'receiver': 'ceyelqpjeeia',
#       'stake_net_quantity': '1.0000 TNT',
#       'stake_cpu_quantity': '1.0000 TNT',
#       'transfer': 0},
#      'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000102700000000000004544e540000000000'},
#     'context_free': False,
#     'elapsed': 258,
#     'console': '',
#     'trx_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#     'block_num': 45353152,
#     'block_time': '2021-01-11T09:35:59.500',
#     'producer_block_id': None,
#     'account_ram_deltas': [],
#     'except': None,
#     'error_code': None,
#     'inline_traces': [{'action_ordinal': 2,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.cbmon',
#        'act_digest': 'a54ecb1795be29cacf5efb70c3e6403cb14f38007574cd1e0aa38541790a879f',
#        'global_sequence': 55795699,
#        'recv_sequence': 3107,
#        'auth_sequence': [['ceyelqpjeeia', 2362]],
#        'code_sequence': 3,
#        'abi_sequence': 3},
#       'receiver': 'eosio.cbmon',
#       'act': {'account': 'eosio',
#        'name': 'delegatebw',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'receiver': 'ceyelqpjeeia',
#         'stake_net_quantity': '1.0000 TNT',
#         'stake_cpu_quantity': '1.0000 TNT',
#         'transfer': 0},
#        'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000102700000000000004544e540000000000'},
#       'context_free': False,
#       'elapsed': 111,
#       'console': '',
#       'trx_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#       'block_num': 45353152,
#       'block_time': '2021-01-11T09:35:59.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': []},
#      {'action_ordinal': 3,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.token',
#        'act_digest': '0b9a8b016dea7e0ab6cd1e367a99d521f55a665814ee67acc566fc751af8f8aa',
#        'global_sequence': 55795700,
#        'recv_sequence': 61612,
#        'auth_sequence': [['ceyelqpjeeia', 2363]],
#        'code_sequence': 1,
#        'abi_sequence': 1},
#       'receiver': 'eosio.token',
#       'act': {'account': 'eosio.token',
#        'name': 'transfer',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'to': 'eosio.stake',
#         'quantity': '2.0000 TNT',
#         'memo': 'stake bandwidth'},
#        'hex_data': '609c52afdaa8bc420014341903ea3055204e00000000000004544e54000000000f7374616b652062616e647769647468'},
#       'context_free': False,
#       'elapsed': 87,
#       'console': '',
#       'trx_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#       'block_num': 45353152,
#       'block_time': '2021-01-11T09:35:59.500',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': [{'action_ordinal': 4,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'ceyelqpjeeia',
#          'act_digest': '0b9a8b016dea7e0ab6cd1e367a99d521f55a665814ee67acc566fc751af8f8aa',
#          'global_sequence': 55795701,
#          'recv_sequence': 3739,
#          'auth_sequence': [['ceyelqpjeeia', 2364]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'ceyelqpjeeia',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.stake',
#           'quantity': '2.0000 TNT',
#           'memo': 'stake bandwidth'},
#          'hex_data': '609c52afdaa8bc420014341903ea3055204e00000000000004544e54000000000f7374616b652062616e647769647468'},
#         'context_free': False,
#         'elapsed': 240,
#         'console': '',
#         'trx_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#         'block_num': 45353152,
#         'block_time': '2021-01-11T09:35:59.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []},
#        {'action_ordinal': 5,
#         'creator_action_ordinal': 3,
#         'closest_unnotified_ancestor_action_ordinal': 3,
#         'receipt': {'receiver': 'eosio.stake',
#          'act_digest': '0b9a8b016dea7e0ab6cd1e367a99d521f55a665814ee67acc566fc751af8f8aa',
#          'global_sequence': 55795702,
#          'recv_sequence': 6172,
#          'auth_sequence': [['ceyelqpjeeia', 2365]],
#          'code_sequence': 1,
#          'abi_sequence': 1},
#         'receiver': 'eosio.stake',
#         'act': {'account': 'eosio.token',
#          'name': 'transfer',
#          'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#          'data': {'from': 'ceyelqpjeeia',
#           'to': 'eosio.stake',
#           'quantity': '2.0000 TNT',
#           'memo': 'stake bandwidth'},
#          'hex_data': '609c52afdaa8bc420014341903ea3055204e00000000000004544e54000000000f7374616b652062616e647769647468'},
#         'context_free': False,
#         'elapsed': 3,
#         'console': '',
#         'trx_id': '1f5cd2fed2db7e4f8368f64fe77f0ef535495481b9631a1cda51bb9b69910611',
#         'block_num': 45353152,
#         'block_time': '2021-01-11T09:35:59.500',
#         'producer_block_id': None,
#         'account_ram_deltas': [],
#         'except': None,
#         'error_code': None,
#         'inline_traces': []}]}]}],
#   'account_ram_delta': None,
#   'except': None,
#   'error_code': None}}

# %% [markdown]
# # def undbw(_from, _to, net, cpu)

# %%
r = uuosapi.get_account(python_contract)['total_resources']
print(r)
r = uuosapi.get_account(python_contract)['cpu_limit']
print(r)
r = uuosapi.get_account(python_contract)['net_limit']
print(r)
print(uuosapi.get_balance(python_contract))
# Out:
# {'owner': 'ceyelqpjeeia', 'net_weight': '4.0000 TNT', 'cpu_weight': '32.0000 TNT', 'ram_bytes': 3874301}
# {'used': 57739, 'available': 14566384, 'max': 14624123}
# {'used': 322504, 'available': 9262483, 'max': 9584987}
# 75.7594

# %%
util.undbw(python_contract, python_contract, 1.0, 1.0)
# Out:
# {'transaction_id': '1e0df623e87a13d2b2aca4a06896254ad1754cfa4d8f90b445bc9cdcbebf3176',
#  'processed': {'id': '1e0df623e87a13d2b2aca4a06896254ad1754cfa4d8f90b445bc9cdcbebf3176',
#   'block_num': 45353235,
#   'block_time': '2021-01-11T09:36:41.000',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 672,
#    'net_usage_words': 23},
#   'elapsed': 672,
#   'net_usage': 184,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': '3c924c7aae8a0d165ec7610cb77b2cb0a3cd984afcc21226b47f703b6bf715b1',
#      'global_sequence': 55795791,
#      'recv_sequence': 45390798,
#      'auth_sequence': [['ceyelqpjeeia', 2366]],
#      'code_sequence': 3,
#      'abi_sequence': 3},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'undelegatebw',
#      'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#      'data': {'from': 'ceyelqpjeeia',
#       'receiver': 'ceyelqpjeeia',
#       'unstake_net_quantity': '1.0000 TNT',
#       'unstake_cpu_quantity': '1.0000 TNT'},
#      'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000102700000000000004544e5400000000'},
#     'context_free': False,
#     'elapsed': 372,
#     'console': '',
#     'trx_id': '1e0df623e87a13d2b2aca4a06896254ad1754cfa4d8f90b445bc9cdcbebf3176',
#     'block_num': 45353235,
#     'block_time': '2021-01-11T09:36:41.000',
#     'producer_block_id': None,
#     'account_ram_deltas': [{'account': 'ceyelqpjeeia', 'delta': 600}],
#     'except': None,
#     'error_code': None,
#     'inline_traces': [{'action_ordinal': 2,
#       'creator_action_ordinal': 1,
#       'closest_unnotified_ancestor_action_ordinal': 1,
#       'receipt': {'receiver': 'eosio.cbmon',
#        'act_digest': '3c924c7aae8a0d165ec7610cb77b2cb0a3cd984afcc21226b47f703b6bf715b1',
#        'global_sequence': 55795792,
#        'recv_sequence': 3108,
#        'auth_sequence': [['ceyelqpjeeia', 2367]],
#        'code_sequence': 3,
#        'abi_sequence': 3},
#       'receiver': 'eosio.cbmon',
#       'act': {'account': 'eosio',
#        'name': 'undelegatebw',
#        'authorization': [{'actor': 'ceyelqpjeeia', 'permission': 'active'}],
#        'data': {'from': 'ceyelqpjeeia',
#         'receiver': 'ceyelqpjeeia',
#         'unstake_net_quantity': '1.0000 TNT',
#         'unstake_cpu_quantity': '1.0000 TNT'},
#        'hex_data': '609c52afdaa8bc42609c52afdaa8bc42102700000000000004544e5400000000102700000000000004544e5400000000'},
#       'context_free': False,
#       'elapsed': 105,
#       'console': '',
#       'trx_id': '1e0df623e87a13d2b2aca4a06896254ad1754cfa4d8f90b445bc9cdcbebf3176',
#       'block_num': 45353235,
#       'block_time': '2021-01-11T09:36:41.000',
#       'producer_block_id': None,
#       'account_ram_deltas': [],
#       'except': None,
#       'error_code': None,
#       'inline_traces': []}]}],
#   'account_ram_delta': None,
#   'except': None,
#   'error_code': None}}

# %%
r = uuosapi.get_account(python_contract)['total_resources']
print(r)
r = uuosapi.get_account(python_contract)['cpu_limit']
print(r)
r = uuosapi.get_account(python_contract)['net_limit']
print(r)
uuosapi.get_balance(python_contract)
uuosapi.get_account(python_contract)['refund_request']
# Out:
# {'owner': 'ceyelqpjeeia', 'net_weight': '3.0000 TNT', 'cpu_weight': '31.0000 TNT', 'ram_bytes': 3874301}
# {'used': 58419, 'available': 14108701, 'max': 14167120}
# {'used': 322535, 'available': 6866205, 'max': 7188740}
# {'owner': 'ceyelqpjeeia',
#  'request_time': '2021-01-11T09:36:41',
#  'net_amount': '1.0000 TNT',
#  'cpu_amount': '1.0000 TNT'}

# %%
eosapi.get_account('helloworld11')
# Out:
# {
#     "account_name": "helloworld11",
#     "head_block_num": 400808,
#     "head_block_time": "2019-06-26T02:53:31.000",
#     "privileged": false,
#     "last_code_update": "2019-06-26T01:56:46.000",
#     "created": "2019-06-21T01:59:21.000",
#     "core_liquid_balance": "107935610.8114 UUOS",
#     "ram_quota": 305438,
#     "net_weight": 1960000,
#     "cpu_weight": 1960000,
#     "net_limit": {
#         "used": 193138,
#         "available": "178462365780731",
#         "max": "178462365973869"
#     },
#     "cpu_limit": {
#         "used": 89223,
#         "available": "34038994885651",
#         "max": "34038994974874"
#     },
#     "ram_usage": 28612,
#     "permissions": [
#         {
#             "perm_name": "active",
#             "parent": "owner",
#             "required_auth": {
#                 "threshold": 1,
#                 "keys": [
#                     {
#                         "key": "EOS7ent7keWbVgvptfYaMYeF2cenMBiwYKcwEuc11uCbStsFKsrmV",
#                         "weight": 1
#                     }
#                 ],
#                 "accounts": [
#                     {
#                         "permission": {
#                             "actor": "helloworld11",
#                             "permission": "eosio.code"
#                         },
#                         "weight": 1
#                     }
#                 ],
#                 "waits": []
#             }
#         },
#         {
#             "perm_name": "owner",
#             "parent": "",
#             "required_auth": {
#                 "threshold": 1,
#                 "keys": [
#                     {
#                         "key": "EOS7ent7keWbVgvptfYaMYeF2cenMBiwYKcwEuc11uCbStsFKsrmV",
#                         "weight": 1
#                     }
#                 ],
#                 "accounts": [
#                     {
#                         "permission": {
#                             "actor": "helloworld11",
#                             "permission": "eosio.code"
#                         },
#                         "weight": 1
#                     }
#                 ],
#                 "waits": []
#             }
#         }
#     ],
#     "total_resources": {
#         "owner": "helloworld11",
#         "net_weight": "196.0000 UUOS",
#         "cpu_weight": "196.0000 UUOS",
#         "ram_bytes": 305438
#     },
#     "self_delegated_bandwidth": {
#         "from": "helloworld11",
#         "to": "helloworld11",
#         "net_weight": "196.0000 UUOS",
#         "cpu_weight": "196.0000 UUOS"
#     },
#     "refund_request": {
#         "owner": "helloworld11",
#         "request_time": "2019-06-26T02:52:47",
#         "net_amount": "1.0000 UUOS",
#         "cpu_amount": "1.0000 UUOS"
#     },
#     "voter_info": {
#         "owner": "helloworld11",
#         "proxy": "",
#         "producers": [],
#         "staked": 3920000,
#         "last_vote_weight": "0.00000000000000000",
#         "proxied_vote_weight": "0.00000000000000000",
#         "is_proxy": 0
#     }
# }
