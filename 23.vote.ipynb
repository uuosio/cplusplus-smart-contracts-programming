# %%
from init import *
#eosapi.set_nodes(['https://nodes.uuos.network:8443'])
eosapi.set_nodes(['http://127.0.0.1:8888'])
config.main_token='UUOS'
wallet.import_key('test', '5KH8vwQkP4QoTwgBtCV5ZYhKmv8mx56WeNrw9AZuhNRXTrPzgYc')
wallet.import_key('test', '5KQwrPbwdL6PhXujxW37FSSQZ1JiwsST4cqQzDeyXtP79zkvFD3')
# Out:
# True

# %%
util.buyrambytes('helloworld11', 'helloworld11', 64*1024)
# Out:
# {'transaction_id': '92145f3abc61d3d17d689ee12fb1fac13e03c0ad77690b6c182467577405d79f',
#  'processed': {'id': '92145f3abc61d3d17d689ee12fb1fac13e03c0ad77690b6c182467577405d79f',
#   'block_num': 547894,
#   'block_time': '2019-08-18T10:23:44.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 942,
#    'net_usage_words': 14},
#   'elapsed': 942,
#   'net_usage': 112,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'b87a115a24bf6a1aeed6cc3d7b6776c9a59dbf4857d0d579bc9d2689720a315d',
#      'global_sequence': 548202,
#      'recv_sequence': 547994,
#      'auth_sequence': [['helloworld11', 246]],
#      'code_sequence': 1,
#      'abi_sequence': 1},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'buyrambytes',
# ...

# %%
from pyeoskit import util
util.dbw('helloworld11', 'helloworld11', 1.0, 1.0)
# Out:
# {'transaction_id': '9c3ea8511f7ed798ff032067119f2d2bd5328643169aaa79b2e497466c30672d',
#  'processed': {'id': '9c3ea8511f7ed798ff032067119f2d2bd5328643169aaa79b2e497466c30672d',
#   'block_num': 547923,
#   'block_time': '2019-08-18T10:23:59.000',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 656,
#    'net_usage_words': 18},
#   'elapsed': 656,
#   'net_usage': 144,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'bbeab8741608998d3387b30fd59ab6a3cb4a0e46e123717cd1bc8e1c8b69827b',
#      'global_sequence': 548238,
#      'recv_sequence': 548024,
#      'auth_sequence': [['helloworld11', 253]],
#      'code_sequence': 1,
#      'abi_sequence': 1},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'delegatebw',
# ...

# %%
eosapi.get_balance('eosio')
# Out:
# 10000000000000.002

# %%
args = {'producer':'eosio', 
        'producer_key':'EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV', 
        'url':'',
        'location':1
       }
eosapi.push_action('eosio', 'regproducer', args, {'eosio':'active'})
# Out:
# {'transaction_id': '897e180f817812c06c79b61b19669dd65edd450bc41911d89eff839a0a9d1061',
#  'processed': {'id': '897e180f817812c06c79b61b19669dd65edd450bc41911d89eff839a0a9d1061',
#   'block_num': 555988,
#   'block_time': '2019-08-18T11:44:20.000',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 566,
#    'net_usage_words': 18},
#   'elapsed': 566,
#   'net_usage': 144,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'ecdd2309577de1570a036889094f1386d92562e064c4962fb4da9c856b0d88cf',
#      'global_sequence': 556312,
#      'recv_sequence': 556095,
#      'auth_sequence': [['eosio', 556017]],
#      'code_sequence': 1,
#      'abi_sequence': 1},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'regproducer',
# ...

# %%
args = {'producer':'helloworld11', 
        'producer_key':'EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV', 
        'url':'',
        'location':1
       }
eosapi.push_action('eosio', 'regproducer', args, {'helloworld11':'active'})
# Out:
# {'transaction_id': 'cd025fc6eb6b9021c39866f665566e4e3b345e434861da64097ef916dd787e6c',
#  'processed': {'id': 'cd025fc6eb6b9021c39866f665566e4e3b345e434861da64097ef916dd787e6c',
#   'block_num': 550580,
#   'block_time': '2019-08-18T10:59:09.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 384,
#    'net_usage_words': 18},
#   'elapsed': 384,
#   'net_usage': 144,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': 'e6433e234ea33f2c5f6ed506dd75bc316ee8434ff24ffac1a09baf98e09ed2d5',
#      'global_sequence': 550902,
#      'recv_sequence': 550685,
#      'auth_sequence': [['helloworld11', 259]],
#      'code_sequence': 1,
#      'abi_sequence': 1},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'regproducer',
# ...

# %%
eosapi.get_producers(True, '', 21)
# Out:
# {
#     "rows": [
#         {
#             "owner": "eosio",
#             "total_votes": "16943584578.41506385803222656",
#             "producer_key": "EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV",
#             "is_active": 1,
#             "url": "",
#             "unpaid_blocks": 0,
#             "last_claim_time": 0,
#             "location": 1
#         },
#         {
#             "owner": "helloworld11",
#             "total_votes": "0.00000000000000000",
#             "producer_key": "EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV",
#             "is_active": 1,
#             "url": "",
#             "unpaid_blocks": 0,
#             "last_claim_time": 0,
#             "location": 1
#         }
#     ],
#     "total_producer_vote_weight": "16943584578.41506385803222656",
#     "more": ""
# }

# %%
args = {'voter':'helloworld11', 'proxy':'', 'producers':['eosio', 'helloworld11']}
eosapi.push_action('eosio', 'voteproducer', args, {'helloworld11':'active'})
# Out:
# {'transaction_id': '3dbb5d258de362ab1e2fefb0ead9ee8de7f0e6c7746890895a72f3cec4ab75e1',
#  'processed': {'id': '3dbb5d258de362ab1e2fefb0ead9ee8de7f0e6c7746890895a72f3cec4ab75e1',
#   'block_num': 550822,
#   'block_time': '2019-08-18T11:01:10.500',
#   'producer_block_id': None,
#   'receipt': {'status': 'executed',
#    'cpu_usage_us': 586,
#    'net_usage_words': 16},
#   'elapsed': 586,
#   'net_usage': 128,
#   'scheduled': False,
#   'action_traces': [{'action_ordinal': 1,
#     'creator_action_ordinal': 0,
#     'closest_unnotified_ancestor_action_ordinal': 0,
#     'receipt': {'receiver': 'eosio',
#      'act_digest': '722fe98eb2937d9d522f7aeb173a46cd424ffd4e004b9bf989481a0d7d2cbfaa',
#      'global_sequence': 551145,
#      'recv_sequence': 550928,
#      'auth_sequence': [['helloworld11', 260]],
#      'code_sequence': 1,
#      'abi_sequence': 1},
#     'receiver': 'eosio',
#     'act': {'account': 'eosio',
#      'name': 'voteproducer',
# ...

# %%
eosapi.get_producers(True, '', 20)
# Out:
# {
#     "rows": [
#         {
#             "owner": "eosio",
#             "total_votes": "16943584578.41506385803222656",
#             "producer_key": "EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV",
#             "is_active": 1,
#             "url": "",
#             "unpaid_blocks": 0,
#             "last_claim_time": 0,
#             "location": 1
#         },
#         {
#             "owner": "helloworld11",
#             "total_votes": "16943584578.41506385803222656",
#             "producer_key": "EOS6MRyAjQq8ud7hVNYcfnVPJqcVpscN5So8BhtHuGYqET5GDW5CV",
#             "is_active": 1,
#             "url": "",
#             "unpaid_blocks": 0,
#             "last_claim_time": 0,
#             "location": 1
#         }
#     ],
#     "total_producer_vote_weight": "33887169156.83012771606445312",
#     "more": ""
# }
